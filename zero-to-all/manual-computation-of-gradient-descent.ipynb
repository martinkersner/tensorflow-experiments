# %%
import tensorflow as tf

# %%
X = [1, 2, 3]
Y = [1, 2, 3]

W = tf.Variable(5.)

# %%
hypothesis = X * W

# %%
gradient = tf.reduce_mean((W * X - Y) * X) * 2

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
gvs = optimizer.compute_gradients(cost, [W])
# gvs = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gvs]
apply_gradients = optimizer.apply_gradients(gvs)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(100):
    print(step, sess.run([gradient, W, gvs]))
#     print(step, sess.run([cost, W, gvs]))
    sess.run(apply_gradients)
# Out:
# (0, [4.6687061e-41, 2.5443861e-29, [(nan, 2.5443861e-29)]])
# (1, [4.2038954e-45, 2.5443861e-29, [(nan, 2.5443861e-29)]])
# (2, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (3, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (4, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (5, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (6, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (7, [0.0, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (8, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (9, [0.0, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (10, [0.0, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (11, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (12, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (13, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (14, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (15, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (16, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (17, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (18, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (19, [0.0, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (20, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (21, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (22, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (23, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (24, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (25, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (26, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (27, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (28, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (29, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (30, [1.4012985e-45, 2.5443861e-29, [(1.4012985e-45, 2.5443861e-29)]])
# (31, [4.2038954e-45, 2.5443861e-29, [(1.4012985e-45, 2.5443861e-29)]])
# (32, [1.4012985e-45, 2.5443861e-29, [(1.4012985e-45, 2.5443861e-29)]])
# (33, [4.2038954e-45, 2.5443861e-29, [(1.4012985e-45, 2.5443861e-29)]])
# (34, [0.0, 2.5443861e-29, [(1.4012985e-45, 2.5443861e-29)]])
# (35, [0.0, 2.5443861e-29, [(1.4012985e-45, 2.5443861e-29)]])
# (36, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (37, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (38, [0.0, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (39, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (40, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (41, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (42, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (43, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (44, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (45, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (46, [0.0, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (47, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (48, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (49, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (50, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (51, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (52, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (53, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (54, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (55, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (56, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (57, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (58, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (59, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (60, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (61, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (62, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (63, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (64, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (65, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (66, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (67, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (68, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (69, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (70, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (71, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (72, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (73, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (74, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (75, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (76, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (77, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (78, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (79, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (80, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (81, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (82, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (83, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (84, [0.0, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (85, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (86, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (87, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (88, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (89, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (90, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (91, [0.0, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (92, [0.0, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (93, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (94, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (95, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (96, [1.4012985e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (97, [0.0, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (98, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
# (99, [4.2038954e-45, 2.5443861e-29, [(4.2038954e-45, 2.5443861e-29)]])
